# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Taylor**

# %% [markdown]
# Data Scientist

# %% [markdown]
# *I am interested in Data Science because I would love to contribute towards affordable and quality healthcare in the future*

# %% [markdown]
# ### This should print my name and my age

# %%
name = "Taylor"
year_of_birth = 1999
recent_year = 2022
age = recent_year - year_of_birth

# %% [markdown]
# - Data Management
# - Data Extraction Transform Load
# - Data Cleaning
# - Data Visualization
#
# 1. Data Science
# 2. Machine Learning
# 3. Artificial Intelligence
# 4. Deep Learning
